# %% [markdown]
# # Minimal dummy example with ictdeploy
# ## Creating a co-simulation graph
# We consider the following two nodes graph as a minimal dummy example of two nodes exchanging a variable and randomly add or substract a given value from it:
#
# <img src="./figures/model.png" alt="Model" style="width: 500px;"/>
#
# The above graph can be created using ictdeploy as follow:

# %%
import os
from ictdeploy import Simulator as Sim

# %%
#create empty simulator
sim = Sim()

# %%
#create Meta-model
sim.edit.add_meta(
        name="BaseMeta",
        set_attrs=["a"],
        get_attrs=["b"]
    )
# Out:
# 'BaseMeta'

# %%
#create Model
sim.edit.add_model(
        name="BaseModel",
        meta="BaseMeta",
        image="integrcity/ict-simple",
        wrapper=os.path.join("wrappers", "base_wrap.py"),
        command=None,
        files=[os.path.join("files_to_add", "empty_file.txt")]
    )
# Out:
# 'BaseModel'

# %% [markdown]
# Now that our `Meta-models` and `Models` have been created, we can populate our `Simulator` with `Nodes` as follow:

# %%
#add node
sim.edit.add_node(
        name="Base0",
        model="BaseModel",
        init_values={"c": 0.5},
        is_first=True
    )
# Out:
# 'Base0'

# %%
#add node
sim.edit.add_node(
        name="Base1",
        model="BaseModel",
        init_values={"c": -0.25},
        is_local=True
    )
# Out:
# 'Base1'

# %% [markdown]
# And add `Links` between the created `Nodes` as follow:

# %%
sim.edit.add_link(get_node="Base0", get_attr="b", set_node="Base1", set_attr="a")
sim.edit.add_link(get_node="Base1", get_attr="b", set_node="Base0", set_attr="a")

# %% [markdown]
# ## Data structure
# The created co-simulation graph can be described by the following tables, gathering information about `Nodes` and `Links`.

# %%
sim.edit.nodes
# Out:
#            meta      model to_set to_get                  image  \
# Base0  BaseMeta  BaseModel    [a]    [b]  integrcity/ict-simple
# Base1  BaseMeta  BaseModel    [a]    [b]  integrcity/ict-simple
#
#                      wrapper                          files command  \
# Base0  wrappers/base_wrap.py  [files_to_add/empty_file.txt]    None
# Base1  wrappers/base_wrap.py  [files_to_add/empty_file.txt]    None
#
#         init_values  is_first  is_local
# Base0    {'c': 0.5}      True     False
# Base1  {'c': -0.25}     False      True

# %%
sim.edit.links
# Out:
#   get_attr get_node set_attr set_node
# 0        b    Base0        a    Base1
# 1        b    Base1        a    Base0

# %% [markdown]
# The co-simulation graph can be plotted using `networkx` and `matplotlib` as follow:

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook
plt.figure(figsize=(5, 2))
g = sim.edit.graph
nx.draw(g, with_labels=True, font_weight='bold')
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# ## Simulation parameters
# Based on the created co-simulation graph, we can now create `Groups`, `Sequence` and `Steps` for the simulation as follow:

# %%
grp0 = sim.create_group("Base0")
grp1 = sim.create_group("Base1")

# %%
sim.create_sequence(grp0, grp1)
sim.create_steps([60] * 10)

# %% [markdown]
# ## Running simulation
# Everything is ready, we just have to run the simulation using `Simulator.run_simulation()`

# %%
logs = sim.run_simulation(server="server.py")
logs["nodes"]["Base1"]
# Out:
# 'python TMP_FOLDER/Base1/base_wrap.py 172.17.01 Base1 init_values.json --i=a --o=b'

# %%
for l in sim.get_logs(logs["orc"]):
    if "INFO" in l:
        print(l)
# Out:
# INFO - 2018-06-12 11:27:49,846 - Connected to 172.17.01/obnl_vhost
# INFO - 2018-06-12 11:27:49,854 - scheduler initialised.
# INFO - 2018-06-12 11:27:50,644 - Simulator Base0 is connected.
# INFO - 2018-06-12 11:28:28,159 - Simulator Base1 is connected.
# INFO - 2018-06-12 11:28:28,159 - Start simulation.
# INFO - 2018-06-12 11:28:28,305 - Simulation finished. Execution time: 0.14588618278503418 seconds

# %% [markdown]
# ## Retrieving results
# Now that the simulation is finished, we can connect to the database of results and list all the available stored values as follow:

# %%
sim.results.connect_to_results_db()
sim.results.list_of_available_results
# Out:
#   IN/OUT   Node Attribute
# 0     IN  Base0         a
# 1    OUT  Base1         b
# 2    OUT  Base0         b
# 3     IN  Base1         a

# %% [markdown]
# Based on the preceding available stored values, we can choose wich results to get using a pattern matching the name of the selected values.

# %%
results = sim.results.get_results_by_pattern("OUT*")
results.keys()
# Out:
# dict_keys(['OUT||Base0||b', 'OUT||Base1||b'])

# %% [markdown]
# And finnaly, we plot the selected results using `matplotlib`.

# %%
plt.figure(figsize=(9, 6))
plt.plot(results['OUT||Base0||b'], "-o", label="Base0 - b", alpha=0.5)
plt.plot(results['OUT||Base1||b'], "-o", label="Base1 - b", alpha=0.5)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="899.9999804930258">
